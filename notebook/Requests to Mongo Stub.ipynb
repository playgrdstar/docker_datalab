# %%
from pymongo import MongoClient
import requests

# %%
# As per Mongo_Check
client = MongoClient('this_mongo')
test_entry = {'Name':'Test Entry 1'}
client.test_database.test_collection.insert_one(test_entry)

# %% [markdown]
# Function to help get the database. Note that the db_name should be a string

# %%
def get_mongo_database(db_name, host='this_mongo'):
    conn = MongoClient('this_mongo')
    return conn[db_name]

# %%
get_mongo_database('test_database')
# Out:
# Database(MongoClient(host=['this_mongo:27017'], document_class=dict, tz_aware=False, connect=True), 'test_database')

# %% [markdown]
# Function to convert collections to dict

# %%
def mongo_collection_to_dicts(dbname='test_database', 
                              collectionname='test_collection',
                              query={}, del_id=True, **kw):

    db = get_mongo_database(dbname, **kw)
    res = list(db[collectionname].find(query))

    if del_id:
        for r in res:
            r.pop('_id')

    return res

# %%
mongo_collection_to_dicts()
# Out:
# [{'Name': 'Test Entry 2'}, {'Name': 'Test Entry 1'}, {'Name': 'Test Entry 1'}]

# %% [markdown]
# Example of a contstructing a REST request

# %%
REST_EU_ROOT_URL = "http://restcountries.eu/rest/v1"

def REST_country_request(field='all', name=None, params=None):

    headers={'User-Agent': 'Mozilla/5.0'} 

    if not params:
        params = {}

    # Get all by appending all to the URL
    if field == 'all':
        return requests.get(REST_EU_ROOT_URL + '/all')
    
    # if not, means there is something in name and /or params

    url = '%s/%s/%s'%(REST_EU_ROOT_URL, field, name)
    print('Requesting URL: ' + url)
    response = requests.get(url, params=params, headers=headers)

    if not response.status_code == 200: 
        raise Exception('Request failed with status code ' + str(response.status_code))

    return response

# %%
response = REST_country_request('currency', 'usd')
# Out:
# Requesting URL: http://restcountries.eu/rest/v1/currency/usd

# %%
response.json()
# Out:
# [{'alpha2Code': 'AS',
#   'alpha3Code': 'ASM',
#   'altSpellings': ['AS', 'Amerika Sāmoa', 'Amelika Sāmoa', 'Sāmoa Amelika'],
#   'area': 199.0,
#   'borders': [],
#   'callingCodes': ['1684'],
#   'capital': 'Pago Pago',
#   'currencies': ['USD'],
#   'demonym': 'American Samoan',
#   'gini': None,
#   'languages': ['en', 'sm'],
#   'latlng': [-14.33333333, -170.0],
#   'name': 'American Samoa',
#   'nativeName': 'American Samoa',
#   'numericCode': '016',
#   'population': 55519,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Polynesia',
#   'timezones': ['UTC-11:00'],
#   'topLevelDomain': ['.as'],
#   'translations': {'de': 'Amerikanisch-Samoa',
#    'es': 'Samoa Americana',
#    'fr': 'Samoa américaines',
#    'it': 'Samoa Americane',
#    'ja': 'アメリカ領サモア'}},
#  {'alpha2Code': 'BQ',
#   'alpha3Code': 'BES',
#   'altSpellings': ['BQ', 'Boneiru'],
#   'area': 294.0,
#   'borders': [],
#   'callingCodes': ['5997'],
#   'capital': 'Kralendijk',
#   'currencies': ['USD'],
#   'demonym': 'Dutch',
#   'gini': None,
#   'languages': ['nl'],
#   'latlng': [12.15, -68.266667],
#   'name': 'Bonaire',
#   'nativeName': 'Bonaire',
#   'numericCode': '535',
#   'population': 17408,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.an', '.nl'],
#   'translations': {'de': None,
#    'es': None,
#    'fr': None,
#    'it': None,
#    'ja': None}},
#  {'alpha2Code': 'IO',
#   'alpha3Code': 'IOT',
#   'altSpellings': ['IO'],
#   'area': 60.0,
#   'borders': [],
#   'callingCodes': ['246'],
#   'capital': 'Diego Garcia',
#   'currencies': ['USD'],
#   'demonym': 'Indian',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [-6.0, 71.5],
#   'name': 'British Indian Ocean Territory',
#   'nativeName': 'British Indian Ocean Territory',
#   'numericCode': '086',
#   'population': 3000,
#   'region': 'Africa',
#   'relevance': '0',
#   'subregion': 'Eastern Africa',
#   'timezones': ['UTC+06:00'],
#   'topLevelDomain': ['.io'],
#   'translations': {'de': 'Britisches Territorium im Indischen Ozean',
#    'es': 'Territorio Británico del Océano Índico',
#    'fr': "Territoire britannique de l'océan Indien",
#    'it': "Territorio britannico dell'oceano indiano",
#    'ja': 'イギリス領インド洋地域'}},
#  {'alpha2Code': 'UM',
#   'alpha3Code': 'UMI',
#   'altSpellings': ['UM'],
#   'area': None,
#   'borders': [],
#   'callingCodes': [''],
#   'capital': '',
#   'currencies': ['USD'],
#   'demonym': 'American',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [],
#   'name': 'United States Minor Outlying Islands',
#   'nativeName': 'United States Minor Outlying Islands',
#   'numericCode': '581',
#   'population': 300,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Northern America',
#   'timezones': ['UTC-11:00', 'UTC-10:00', 'UTC+12:00'],
#   'topLevelDomain': ['.us'],
#   'translations': {'de': 'Kleinere Inselbesitzungen der Vereinigten Staaten',
#    'es': 'Islas Ultramarinas Menores de Estados Unidos',
#    'fr': 'Îles mineures éloignées des États-Unis',
#    'it': "Isole minori esterne degli Stati Uniti d'America",
#    'ja': '合衆国領有小離島'}},
#  {'alpha2Code': 'VG',
#   'alpha3Code': 'VGB',
#   'altSpellings': ['VG'],
#   'area': 151.0,
#   'borders': [],
#   'callingCodes': ['1284'],
#   'capital': 'Road Town',
#   'currencies': ['USD'],
#   'demonym': 'Virgin Islander',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [18.431383, -64.62305],
#   'name': 'Virgin Islands (British)',
#   'nativeName': 'British Virgin Islands',
#   'numericCode': '092',
#   'population': 28054,
#   'region': 'Americas',
#   'relevance': '0.5',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.vg'],
#   'translations': {'de': 'Britische Jungferninseln',
#    'es': 'Islas Vírgenes del Reino Unido',
#    'fr': 'Îles Vierges britanniques',
#    'it': 'Isole Vergini Britanniche',
#    'ja': 'イギリス領ヴァージン諸島'}},
#  {'alpha2Code': 'VI',
#   'alpha3Code': 'VIR',
#   'altSpellings': ['VI',
#    'USVI',
#    'American Virgin Islands',
#    'U.S. Virgin Islands'],
#   'area': 346.36,
#   'borders': [],
#   'callingCodes': ['1 340'],
#   'capital': 'Charlotte Amalie',
#   'currencies': ['USD'],
#   'demonym': 'Virgin Islander',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [18.34, -64.93],
#   'name': 'Virgin Islands (U.S.)',
#   'nativeName': 'Virgin Islands of the United States',
#   'numericCode': '850',
#   'population': 114743,
#   'region': 'Americas',
#   'relevance': '0.5',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.vi'],
#   'translations': {'de': 'Amerikanische Jungferninseln',
#    'es': 'Islas Vírgenes de los Estados Unidos',
#    'fr': 'Îles Vierges des États-Unis',
#    'it': 'Isole Vergini americane',
#    'ja': 'アメリカ領ヴァージン諸島'}},
#  {'alpha2Code': 'EC',
#   'alpha3Code': 'ECU',
#   'altSpellings': ['EC', 'Republic of Ecuador', 'República del Ecuador'],
#   'area': 276841.0,
#   'borders': ['COL', 'PER'],
#   'callingCodes': ['593'],
#   'capital': 'Quito',
#   'currencies': ['USD'],
#   'demonym': 'Ecuadorean',
#   'gini': 49.3,
#   'languages': ['es'],
#   'latlng': [-2.0, -77.5],
#   'name': 'Ecuador',
#   'nativeName': 'Ecuador',
#   'numericCode': '218',
#   'population': 16027500,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'South America',
#   'timezones': ['UTC-06:00', 'UTC-05:00'],
#   'topLevelDomain': ['.ec'],
#   'translations': {'de': 'Ecuador',
#    'es': 'Ecuador',
#    'fr': 'Équateur',
#    'it': 'Ecuador',
#    'ja': 'エクアドル'}},
#  {'alpha2Code': 'SV',
#   'alpha3Code': 'SLV',
#   'altSpellings': ['SV',
#    'Republic of El Salvador',
#    'República de El Salvador'],
#   'area': 21041.0,
#   'borders': ['GTM', 'HND'],
#   'callingCodes': ['503'],
#   'capital': 'San Salvador',
#   'currencies': ['SVC', 'USD'],
#   'demonym': 'Salvadoran',
#   'gini': 48.3,
#   'languages': ['es'],
#   'latlng': [13.83333333, -88.91666666],
#   'name': 'El Salvador',
#   'nativeName': 'El Salvador',
#   'numericCode': '222',
#   'population': 6401240,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Central America',
#   'timezones': ['UTC-06:00'],
#   'topLevelDomain': ['.sv'],
#   'translations': {'de': 'El Salvador',
#    'es': 'El Salvador',
#    'fr': 'Salvador',
#    'it': 'El Salvador',
#    'ja': 'エルサルバドル'}},
#  {'alpha2Code': 'GU',
#   'alpha3Code': 'GUM',
#   'altSpellings': ['GU', 'Guåhån'],
#   'area': 549.0,
#   'borders': [],
#   'callingCodes': ['1671'],
#   'capital': 'Hagåtña',
#   'currencies': ['USD'],
#   'demonym': 'Guamanian',
#   'gini': None,
#   'languages': ['en', 'ch', 'es'],
#   'latlng': [13.46666666, 144.78333333],
#   'name': 'Guam',
#   'nativeName': 'Guam',
#   'numericCode': '316',
#   'population': 159358,
#   'region': 'Oceania',
#   'relevance': '0',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+10:00'],
#   'topLevelDomain': ['.gu'],
#   'translations': {'de': 'Guam',
#    'es': 'Guam',
#    'fr': 'Guam',
#    'it': 'Guam',
#    'ja': 'グアム'}},
#  {'alpha2Code': 'HT',
#   'alpha3Code': 'HTI',
#   'altSpellings': ['HT',
#    'Republic of Haiti',
#    "République d'Haïti",
#    'Repiblik Ayiti'],
#   'area': 27750.0,
#   'borders': ['DOM'],
#   'callingCodes': ['509'],
#   'capital': 'Port-au-Prince',
#   'currencies': ['HTG', 'USD'],
#   'demonym': 'Haitian',
#   'gini': 59.2,
#   'languages': ['fr', 'ht'],
#   'latlng': [19.0, -72.41666666],
#   'name': 'Haiti',
#   'nativeName': 'Haïti',
#   'numericCode': '332',
#   'population': 10911819,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-05:00'],
#   'topLevelDomain': ['.ht'],
#   'translations': {'de': 'Haiti',
#    'es': 'Haiti',
#    'fr': 'Haïti',
#    'it': 'Haiti',
#    'ja': 'ハイチ'}},
#  {'alpha2Code': 'MH',
#   'alpha3Code': 'MHL',
#   'altSpellings': ['MH',
#    'Republic of the Marshall Islands',
#    'Aolepān Aorōkin M̧ajeļ'],
#   'area': 181.0,
#   'borders': [],
#   'callingCodes': ['692'],
#   'capital': 'Majuro',
#   'currencies': ['USD'],
#   'demonym': 'Marshallese',
#   'gini': None,
#   'languages': ['en', 'mh'],
#   'latlng': [9.0, 168.0],
#   'name': 'Marshall Islands',
#   'nativeName': 'M̧ajeļ',
#   'numericCode': '584',
#   'population': 56086,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+12:00'],
#   'topLevelDomain': ['.mh'],
#   'translations': {'de': 'Marshallinseln',
#    'es': 'Islas Marshall',
#    'fr': 'Îles Marshall',
#    'it': 'Isole Marshall',
#    'ja': 'マーシャル諸島'}},
#  {'alpha2Code': 'FM',
#   'alpha3Code': 'FSM',
#   'altSpellings': ['FM', 'Federated States of Micronesia'],
#   'area': 702.0,
#   'borders': [],
#   'callingCodes': ['691'],
#   'capital': 'Palikir',
#   'currencies': ['USD'],
#   'demonym': 'Micronesian',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [6.91666666, 158.25],
#   'name': 'Federated States of Micronesia',
#   'nativeName': 'Micronesia',
#   'numericCode': '583',
#   'population': 101351,
#   'region': 'Oceania',
#   'relevance': '0',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+10:00', 'UTC+11'],
#   'topLevelDomain': ['.fm'],
#   'translations': {'de': 'Mikronesien',
#    'es': 'Micronesia',
#    'fr': 'Micronésie',
#    'it': 'Micronesia',
#    'ja': 'ミクロネシア連邦'}},
#  {'alpha2Code': 'MP',
#   'alpha3Code': 'MNP',
#   'altSpellings': ['MP',
#    'Commonwealth of the Northern Mariana Islands',
#    'Sankattan Siha Na Islas Mariånas'],
#   'area': 464.0,
#   'borders': [],
#   'callingCodes': ['1670'],
#   'capital': 'Saipan',
#   'currencies': ['USD'],
#   'demonym': 'American',
#   'gini': None,
#   'languages': ['en', 'ch'],
#   'latlng': [15.2, 145.75],
#   'name': 'Northern Mariana Islands',
#   'nativeName': 'Northern Mariana Islands',
#   'numericCode': '580',
#   'population': 53883,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+10:00'],
#   'topLevelDomain': ['.mp'],
#   'translations': {'de': 'Nördliche Marianen',
#    'es': 'Islas Marianas del Norte',
#    'fr': 'Îles Mariannes du Nord',
#    'it': 'Isole Marianne Settentrionali',
#    'ja': '北マリアナ諸島'}},
#  {'alpha2Code': 'PW',
#   'alpha3Code': 'PLW',
#   'altSpellings': ['PW', 'Republic of Palau', 'Beluu er a Belau'],
#   'area': 459.0,
#   'borders': [],
#   'callingCodes': ['680'],
#   'capital': 'Ngerulmud',
#   'currencies': ['USD'],
#   'demonym': 'Palauan',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [7.5, 134.5],
#   'name': 'Palau',
#   'nativeName': 'Palau',
#   'numericCode': '585',
#   'population': 20901,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+09:00'],
#   'topLevelDomain': ['.pw'],
#   'translations': {'de': 'Palau',
#    'es': 'Palau',
#    'fr': 'Palaos',
#    'it': 'Palau',
#    'ja': 'パラオ'}},
#  {'alpha2Code': 'PA',
#   'alpha3Code': 'PAN',
#   'altSpellings': ['PA', 'Republic of Panama', 'República de Panamá'],
#   'area': 75417.0,
#   'borders': ['COL', 'CRI'],
#   'callingCodes': ['507'],
#   'capital': 'Panama City',
#   'currencies': ['PAB', 'USD'],
#   'demonym': 'Panamanian',
#   'gini': 51.9,
#   'languages': ['es'],
#   'latlng': [9.0, -80.0],
#   'name': 'Panama',
#   'nativeName': 'Panamá',
#   'numericCode': '591',
#   'population': 3764166,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Central America',
#   'timezones': ['UTC-05:00'],
#   'topLevelDomain': ['.pa'],
#   'translations': {'de': 'Panama',
#    'es': 'Panamá',
#    'fr': 'Panama',
#    'it': 'Panama',
#    'ja': 'パナマ'}},
#  {'alpha2Code': 'PR',
#   'alpha3Code': 'PRI',
#   'altSpellings': ['PR',
#    'Commonwealth of Puerto Rico',
#    'Estado Libre Asociado de Puerto Rico'],
#   'area': 8870.0,
#   'borders': [],
#   'callingCodes': ['1787', '1939'],
#   'capital': 'San Juan',
#   'currencies': ['USD'],
#   'demonym': 'Puerto Rican',
#   'gini': None,
#   'languages': ['es', 'en'],
#   'latlng': [18.25, -66.5],
#   'name': 'Puerto Rico',
#   'nativeName': 'Puerto Rico',
#   'numericCode': '630',
#   'population': 3548397,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.pr'],
#   'translations': {'de': 'Puerto Rico',
#    'es': 'Puerto Rico',
#    'fr': 'Porto Rico',
#    'it': 'Porto Rico',
#    'ja': 'プエルトリコ'}},
#  {'alpha2Code': 'TL',
#   'alpha3Code': 'TLS',
#   'altSpellings': ['TL',
#    'East Timor',
#    'Democratic Republic of Timor-Leste',
#    'República Democrática de Timor-Leste',
#    'Repúblika Demokrátika Timór-Leste'],
#   'area': 14874.0,
#   'borders': ['IDN'],
#   'callingCodes': ['670'],
#   'capital': 'Dili',
#   'currencies': ['USD'],
#   'demonym': 'East Timorese',
#   'gini': 31.9,
#   'languages': ['pt'],
#   'latlng': [-8.83333333, 125.91666666],
#   'name': 'East Timor',
#   'nativeName': 'Timor-Leste',
#   'numericCode': '626',
#   'population': 1212107,
#   'region': 'Asia',
#   'relevance': '0',
#   'subregion': 'South-Eastern Asia',
#   'timezones': ['UTC+09:00'],
#   'topLevelDomain': ['.tl'],
#   'translations': {'de': 'Timor-Leste',
#    'es': 'Timor Oriental',
#    'fr': 'Timor oriental',
#    'it': 'Timor Est',
#    'ja': '東ティモール'}},
#  {'alpha2Code': 'TC',
#   'alpha3Code': 'TCA',
#   'altSpellings': ['TC'],
#   'area': 948.0,
#   'borders': [],
#   'callingCodes': ['1649'],
#   'capital': 'Cockburn Town',
#   'currencies': ['USD'],
#   'demonym': 'Turks and Caicos Islander',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [21.75, -71.58333333],
#   'name': 'Turks and Caicos Islands',
#   'nativeName': 'Turks and Caicos Islands',
#   'numericCode': '796',
#   'population': 31458,
#   'region': 'Americas',
#   'relevance': '0.5',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.tc'],
#   'translations': {'de': 'Turks- und Caicosinseln',
#    'es': 'Islas Turks y Caicos',
#    'fr': 'Îles Turques-et-Caïques',
#    'it': 'Isole Turks e Caicos',
#    'ja': 'タークス・カイコス諸島'}},
#  {'alpha2Code': 'US',
#   'alpha3Code': 'USA',
#   'altSpellings': ['US', 'USA', 'United States of America'],
#   'area': 9629091.0,
#   'borders': ['CAN', 'MEX'],
#   'callingCodes': ['1'],
#   'capital': 'Washington, D.C.',
#   'currencies': ['USD', 'USN', 'USS'],
#   'demonym': 'American',
#   'gini': 48.0,
#   'languages': ['en'],
#   'latlng': [38.0, -97.0],
#   'name': 'United States',
#   'nativeName': 'United States',
#   'numericCode': '840',
#   'population': 321645000,
#   'region': 'Americas',
#   'relevance': '3.5',
#   'subregion': 'Northern America',
#   'timezones': ['UTC-12:00',
#    'UTC-11:00',
#    'UTC-10:00',
#    'UTC-09:00',
#    'UTC-08:00',
#    'UTC-07:00',
#    'UTC-06:00',
#    'UTC-05:00',
#    'UTC-04:00',
#    'UTC+10:00',
#    'UTC+12:00'],
#   'topLevelDomain': ['.us'],
#   'translations': {'de': 'Vereinigte Staaten von Amerika',
#    'es': 'Estados Unidos',
#    'fr': 'États-Unis',
#    'it': "Stati Uniti D'America",
#    'ja': 'アメリカ合衆国'}},
#  {'alpha2Code': 'ZW',
#   'alpha3Code': 'ZWE',
#   'altSpellings': ['ZW', 'Republic of Zimbabwe'],
#   'area': 390757.0,
#   'borders': ['BWA', 'MOZ', 'ZAF', 'ZMB'],
#   'callingCodes': ['263'],
#   'capital': 'Harare',
#   'currencies': ['USD'],
#   'demonym': 'Zimbabwean',
#   'gini': None,
#   'languages': ['en', 'sn', 'nd'],
#   'latlng': [-20.0, 30.0],
#   'name': 'Zimbabwe',
#   'nativeName': 'Zimbabwe',
#   'numericCode': '716',
#   'population': 13061239,
#   'region': 'Africa',
#   'relevance': '0',
#   'subregion': 'Eastern Africa',
#   'timezones': ['UTC+02:00'],
#   'topLevelDomain': ['.zw'],
#   'translations': {'de': 'Simbabwe',
#    'es': 'Zimbabue',
#    'fr': 'Zimbabwe',
#    'it': 'Zimbabwe',
#    'ja': 'ジンバブエ'}}]

# %%
test_db = get_mongo_database('test_database')

# %%
collect = test_db['country_data']

# %%
# get all country data
response = REST_country_request()

# %%
collect.insert(response.json())
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# [ObjectId('59e039121f7b2b002856ac31'),
#  ObjectId('59e039121f7b2b002856ac32'),
#  ObjectId('59e039121f7b2b002856ac33'),
#  ObjectId('59e039121f7b2b002856ac34'),
#  ObjectId('59e039121f7b2b002856ac35'),
#  ObjectId('59e039121f7b2b002856ac36'),
#  ObjectId('59e039121f7b2b002856ac37'),
#  ObjectId('59e039121f7b2b002856ac38'),
#  ObjectId('59e039121f7b2b002856ac39'),
#  ObjectId('59e039121f7b2b002856ac3a'),
#  ObjectId('59e039121f7b2b002856ac3b'),
#  ObjectId('59e039121f7b2b002856ac3c'),
#  ObjectId('59e039121f7b2b002856ac3d'),
#  ObjectId('59e039121f7b2b002856ac3e'),
#  ObjectId('59e039121f7b2b002856ac3f'),
#  ObjectId('59e039121f7b2b002856ac40'),
#  ObjectId('59e039121f7b2b002856ac41'),
#  ObjectId('59e039121f7b2b002856ac42'),
#  ObjectId('59e039121f7b2b002856ac43'),
#  ObjectId('59e039121f7b2b002856ac44'),
#  ObjectId('59e039121f7b2b002856ac45'),
#  ObjectId('59e039121f7b2b002856ac46'),
#  ObjectId('59e039121f7b2b002856ac47'),
#  ObjectId('59e039121f7b2b002856ac48'),
#  ObjectId('59e039121f7b2b002856ac49'),
#  ObjectId('59e039121f7b2b002856ac4a'),
#  ObjectId('59e039121f7b2b002856ac4b'),
#  ObjectId('59e039121f7b2b002856ac4c'),
#  ObjectId('59e039121f7b2b002856ac4d'),
#  ObjectId('59e039121f7b2b002856ac4e'),
#  ObjectId('59e039121f7b2b002856ac4f'),
#  ObjectId('59e039121f7b2b002856ac50'),
#  ObjectId('59e039121f7b2b002856ac51'),
#  ObjectId('59e039121f7b2b002856ac52'),
#  ObjectId('59e039121f7b2b002856ac53'),
#  ObjectId('59e039121f7b2b002856ac54'),
#  ObjectId('59e039121f7b2b002856ac55'),
#  ObjectId('59e039121f7b2b002856ac56'),
#  ObjectId('59e039121f7b2b002856ac57'),
#  ObjectId('59e039121f7b2b002856ac58'),
#  ObjectId('59e039121f7b2b002856ac59'),
#  ObjectId('59e039121f7b2b002856ac5a'),
#  ObjectId('59e039121f7b2b002856ac5b'),
#  ObjectId('59e039121f7b2b002856ac5c'),
#  ObjectId('59e039121f7b2b002856ac5d'),
#  ObjectId('59e039121f7b2b002856ac5e'),
#  ObjectId('59e039121f7b2b002856ac5f'),
#  ObjectId('59e039121f7b2b002856ac60'),
#  ObjectId('59e039121f7b2b002856ac61'),
#  ObjectId('59e039121f7b2b002856ac62'),
#  ObjectId('59e039121f7b2b002856ac63'),
#  ObjectId('59e039121f7b2b002856ac64'),
#  ObjectId('59e039121f7b2b002856ac65'),
#  ObjectId('59e039121f7b2b002856ac66'),
#  ObjectId('59e039121f7b2b002856ac67'),
#  ObjectId('59e039121f7b2b002856ac68'),
#  ObjectId('59e039121f7b2b002856ac69'),
#  ObjectId('59e039121f7b2b002856ac6a'),
#  ObjectId('59e039121f7b2b002856ac6b'),
#  ObjectId('59e039121f7b2b002856ac6c'),
#  ObjectId('59e039121f7b2b002856ac6d'),
#  ObjectId('59e039121f7b2b002856ac6e'),
#  ObjectId('59e039121f7b2b002856ac6f'),
#  ObjectId('59e039121f7b2b002856ac70'),
#  ObjectId('59e039121f7b2b002856ac71'),
#  ObjectId('59e039121f7b2b002856ac72'),
#  ObjectId('59e039121f7b2b002856ac73'),
#  ObjectId('59e039121f7b2b002856ac74'),
#  ObjectId('59e039121f7b2b002856ac75'),
#  ObjectId('59e039121f7b2b002856ac76'),
#  ObjectId('59e039121f7b2b002856ac77'),
#  ObjectId('59e039121f7b2b002856ac78'),
#  ObjectId('59e039121f7b2b002856ac79'),
#  ObjectId('59e039121f7b2b002856ac7a'),
#  ObjectId('59e039121f7b2b002856ac7b'),
#  ObjectId('59e039121f7b2b002856ac7c'),
#  ObjectId('59e039121f7b2b002856ac7d'),
#  ObjectId('59e039121f7b2b002856ac7e'),
#  ObjectId('59e039121f7b2b002856ac7f'),
#  ObjectId('59e039121f7b2b002856ac80'),
#  ObjectId('59e039121f7b2b002856ac81'),
#  ObjectId('59e039121f7b2b002856ac82'),
#  ObjectId('59e039121f7b2b002856ac83'),
#  ObjectId('59e039121f7b2b002856ac84'),
#  ObjectId('59e039121f7b2b002856ac85'),
#  ObjectId('59e039121f7b2b002856ac86'),
#  ObjectId('59e039121f7b2b002856ac87'),
#  ObjectId('59e039121f7b2b002856ac88'),
#  ObjectId('59e039121f7b2b002856ac89'),
#  ObjectId('59e039121f7b2b002856ac8a'),
#  ObjectId('59e039121f7b2b002856ac8b'),
#  ObjectId('59e039121f7b2b002856ac8c'),
#  ObjectId('59e039121f7b2b002856ac8d'),
#  ObjectId('59e039121f7b2b002856ac8e'),
#  ObjectId('59e039121f7b2b002856ac8f'),
#  ObjectId('59e039121f7b2b002856ac90'),
#  ObjectId('59e039121f7b2b002856ac91'),
#  ObjectId('59e039121f7b2b002856ac92'),
#  ObjectId('59e039121f7b2b002856ac93'),
#  ObjectId('59e039121f7b2b002856ac94'),
#  ObjectId('59e039121f7b2b002856ac95'),
#  ObjectId('59e039121f7b2b002856ac96'),
#  ObjectId('59e039121f7b2b002856ac97'),
#  ObjectId('59e039121f7b2b002856ac98'),
#  ObjectId('59e039121f7b2b002856ac99'),
#  ObjectId('59e039121f7b2b002856ac9a'),
#  ObjectId('59e039121f7b2b002856ac9b'),
#  ObjectId('59e039121f7b2b002856ac9c'),
#  ObjectId('59e039121f7b2b002856ac9d'),
#  ObjectId('59e039121f7b2b002856ac9e'),
#  ObjectId('59e039121f7b2b002856ac9f'),
#  ObjectId('59e039121f7b2b002856aca0'),
#  ObjectId('59e039121f7b2b002856aca1'),
#  ObjectId('59e039121f7b2b002856aca2'),
#  ObjectId('59e039121f7b2b002856aca3'),
#  ObjectId('59e039121f7b2b002856aca4'),
#  ObjectId('59e039121f7b2b002856aca5'),
#  ObjectId('59e039121f7b2b002856aca6'),
#  ObjectId('59e039121f7b2b002856aca7'),
#  ObjectId('59e039121f7b2b002856aca8'),
#  ObjectId('59e039121f7b2b002856aca9'),
#  ObjectId('59e039121f7b2b002856acaa'),
#  ObjectId('59e039121f7b2b002856acab'),
#  ObjectId('59e039121f7b2b002856acac'),
#  ObjectId('59e039121f7b2b002856acad'),
#  ObjectId('59e039121f7b2b002856acae'),
#  ObjectId('59e039121f7b2b002856acaf'),
#  ObjectId('59e039121f7b2b002856acb0'),
#  ObjectId('59e039121f7b2b002856acb1'),
#  ObjectId('59e039121f7b2b002856acb2'),
#  ObjectId('59e039121f7b2b002856acb3'),
#  ObjectId('59e039121f7b2b002856acb4'),
#  ObjectId('59e039121f7b2b002856acb5'),
#  ObjectId('59e039121f7b2b002856acb6'),
#  ObjectId('59e039121f7b2b002856acb7'),
#  ObjectId('59e039121f7b2b002856acb8'),
#  ObjectId('59e039121f7b2b002856acb9'),
#  ObjectId('59e039121f7b2b002856acba'),
#  ObjectId('59e039121f7b2b002856acbb'),
#  ObjectId('59e039121f7b2b002856acbc'),
#  ObjectId('59e039121f7b2b002856acbd'),
#  ObjectId('59e039121f7b2b002856acbe'),
#  ObjectId('59e039121f7b2b002856acbf'),
#  ObjectId('59e039121f7b2b002856acc0'),
#  ObjectId('59e039121f7b2b002856acc1'),
#  ObjectId('59e039121f7b2b002856acc2'),
#  ObjectId('59e039121f7b2b002856acc3'),
#  ObjectId('59e039121f7b2b002856acc4'),
#  ObjectId('59e039121f7b2b002856acc5'),
#  ObjectId('59e039121f7b2b002856acc6'),
#  ObjectId('59e039121f7b2b002856acc7'),
#  ObjectId('59e039121f7b2b002856acc8'),
#  ObjectId('59e039121f7b2b002856acc9'),
#  ObjectId('59e039121f7b2b002856acca'),
#  ObjectId('59e039121f7b2b002856accb'),
#  ObjectId('59e039121f7b2b002856accc'),
#  ObjectId('59e039121f7b2b002856accd'),
#  ObjectId('59e039121f7b2b002856acce'),
#  ObjectId('59e039121f7b2b002856accf'),
#  ObjectId('59e039121f7b2b002856acd0'),
#  ObjectId('59e039121f7b2b002856acd1'),
#  ObjectId('59e039121f7b2b002856acd2'),
#  ObjectId('59e039121f7b2b002856acd3'),
#  ObjectId('59e039121f7b2b002856acd4'),
#  ObjectId('59e039121f7b2b002856acd5'),
#  ObjectId('59e039121f7b2b002856acd6'),
#  ObjectId('59e039121f7b2b002856acd7'),
#  ObjectId('59e039121f7b2b002856acd8'),
#  ObjectId('59e039121f7b2b002856acd9'),
#  ObjectId('59e039121f7b2b002856acda'),
#  ObjectId('59e039121f7b2b002856acdb'),
#  ObjectId('59e039121f7b2b002856acdc'),
#  ObjectId('59e039121f7b2b002856acdd'),
#  ObjectId('59e039121f7b2b002856acde'),
#  ObjectId('59e039121f7b2b002856acdf'),
#  ObjectId('59e039121f7b2b002856ace0'),
#  ObjectId('59e039121f7b2b002856ace1'),
#  ObjectId('59e039121f7b2b002856ace2'),
#  ObjectId('59e039121f7b2b002856ace3'),
#  ObjectId('59e039121f7b2b002856ace4'),
#  ObjectId('59e039121f7b2b002856ace5'),
#  ObjectId('59e039121f7b2b002856ace6'),
#  ObjectId('59e039121f7b2b002856ace7'),
#  ObjectId('59e039121f7b2b002856ace8'),
#  ObjectId('59e039121f7b2b002856ace9'),
#  ObjectId('59e039121f7b2b002856acea'),
#  ObjectId('59e039121f7b2b002856aceb'),
#  ObjectId('59e039121f7b2b002856acec'),
#  ObjectId('59e039121f7b2b002856aced'),
#  ObjectId('59e039121f7b2b002856acee'),
#  ObjectId('59e039121f7b2b002856acef'),
#  ObjectId('59e039121f7b2b002856acf0'),
#  ObjectId('59e039121f7b2b002856acf1'),
#  ObjectId('59e039121f7b2b002856acf2'),
#  ObjectId('59e039121f7b2b002856acf3'),
#  ObjectId('59e039121f7b2b002856acf4'),
#  ObjectId('59e039121f7b2b002856acf5'),
#  ObjectId('59e039121f7b2b002856acf6'),
#  ObjectId('59e039121f7b2b002856acf7'),
#  ObjectId('59e039121f7b2b002856acf8'),
#  ObjectId('59e039121f7b2b002856acf9'),
#  ObjectId('59e039121f7b2b002856acfa'),
#  ObjectId('59e039121f7b2b002856acfb'),
#  ObjectId('59e039121f7b2b002856acfc'),
#  ObjectId('59e039121f7b2b002856acfd'),
#  ObjectId('59e039121f7b2b002856acfe'),
#  ObjectId('59e039121f7b2b002856acff'),
#  ObjectId('59e039121f7b2b002856ad00'),
#  ObjectId('59e039121f7b2b002856ad01'),
#  ObjectId('59e039121f7b2b002856ad02'),
#  ObjectId('59e039121f7b2b002856ad03'),
#  ObjectId('59e039121f7b2b002856ad04'),
#  ObjectId('59e039121f7b2b002856ad05'),
#  ObjectId('59e039121f7b2b002856ad06'),
#  ObjectId('59e039121f7b2b002856ad07'),
#  ObjectId('59e039121f7b2b002856ad08'),
#  ObjectId('59e039121f7b2b002856ad09'),
#  ObjectId('59e039121f7b2b002856ad0a'),
#  ObjectId('59e039121f7b2b002856ad0b'),
#  ObjectId('59e039121f7b2b002856ad0c'),
#  ObjectId('59e039121f7b2b002856ad0d'),
#  ObjectId('59e039121f7b2b002856ad0e'),
#  ObjectId('59e039121f7b2b002856ad0f'),
#  ObjectId('59e039121f7b2b002856ad10'),
#  ObjectId('59e039121f7b2b002856ad11'),
#  ObjectId('59e039121f7b2b002856ad12'),
#  ObjectId('59e039121f7b2b002856ad13'),
#  ObjectId('59e039121f7b2b002856ad14'),
#  ObjectId('59e039121f7b2b002856ad15'),
#  ObjectId('59e039121f7b2b002856ad16'),
#  ObjectId('59e039121f7b2b002856ad17'),
#  ObjectId('59e039121f7b2b002856ad18'),
#  ObjectId('59e039121f7b2b002856ad19'),
#  ObjectId('59e039121f7b2b002856ad1a'),
#  ObjectId('59e039121f7b2b002856ad1b'),
#  ObjectId('59e039121f7b2b002856ad1c'),
#  ObjectId('59e039121f7b2b002856ad1d'),
#  ObjectId('59e039121f7b2b002856ad1e'),
#  ObjectId('59e039121f7b2b002856ad1f'),
#  ObjectId('59e039121f7b2b002856ad20'),
#  ObjectId('59e039121f7b2b002856ad21'),
#  ObjectId('59e039121f7b2b002856ad22'),
#  ObjectId('59e039121f7b2b002856ad23'),
#  ObjectId('59e039121f7b2b002856ad24'),
#  ObjectId('59e039121f7b2b002856ad25'),
#  ObjectId('59e039121f7b2b002856ad26'),
#  ObjectId('59e039121f7b2b002856ad27'),
#  ObjectId('59e039121f7b2b002856ad28'),
#  ObjectId('59e039121f7b2b002856ad29'),
#  ObjectId('59e039121f7b2b002856ad2a')]

# %%
res = collect.find({'currencies':{'$in':['USD']}})

# %%
list(res)
# Out:
# [{'_id': ObjectId('59e039121f7b2b002856ac35'),
#   'alpha2Code': 'AS',
#   'alpha3Code': 'ASM',
#   'altSpellings': ['AS', 'Amerika Sāmoa', 'Amelika Sāmoa', 'Sāmoa Amelika'],
#   'area': 199.0,
#   'borders': [],
#   'callingCodes': ['1684'],
#   'capital': 'Pago Pago',
#   'currencies': ['USD'],
#   'demonym': 'American Samoan',
#   'gini': None,
#   'languages': ['en', 'sm'],
#   'latlng': [-14.33333333, -170.0],
#   'name': 'American Samoa',
#   'nativeName': 'American Samoa',
#   'numericCode': '016',
#   'population': 55519,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Polynesia',
#   'timezones': ['UTC-11:00'],
#   'topLevelDomain': ['.as'],
#   'translations': {'de': 'Amerikanisch-Samoa',
#    'es': 'Samoa Americana',
#    'fr': 'Samoa américaines',
#    'it': 'Samoa Americane',
#    'ja': 'アメリカ領サモア'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac4c'),
#   'alpha2Code': 'BQ',
#   'alpha3Code': 'BES',
#   'altSpellings': ['BQ', 'Boneiru'],
#   'area': 294.0,
#   'borders': [],
#   'callingCodes': ['5997'],
#   'capital': 'Kralendijk',
#   'currencies': ['USD'],
#   'demonym': 'Dutch',
#   'gini': None,
#   'languages': ['nl'],
#   'latlng': [12.15, -68.266667],
#   'name': 'Bonaire',
#   'nativeName': 'Bonaire',
#   'numericCode': '535',
#   'population': 17408,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.an', '.nl'],
#   'translations': {'de': None,
#    'es': None,
#    'fr': None,
#    'it': None,
#    'ja': None}},
#  {'_id': ObjectId('59e039121f7b2b002856ac51'),
#   'alpha2Code': 'IO',
#   'alpha3Code': 'IOT',
#   'altSpellings': ['IO'],
#   'area': 60.0,
#   'borders': [],
#   'callingCodes': ['246'],
#   'capital': 'Diego Garcia',
#   'currencies': ['USD'],
#   'demonym': 'Indian',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [-6.0, 71.5],
#   'name': 'British Indian Ocean Territory',
#   'nativeName': 'British Indian Ocean Territory',
#   'numericCode': '086',
#   'population': 3000,
#   'region': 'Africa',
#   'relevance': '0',
#   'subregion': 'Eastern Africa',
#   'timezones': ['UTC+06:00'],
#   'topLevelDomain': ['.io'],
#   'translations': {'de': 'Britisches Territorium im Indischen Ozean',
#    'es': 'Territorio Británico del Océano Índico',
#    'fr': "Territoire britannique de l'océan Indien",
#    'it': "Territorio britannico dell'oceano indiano",
#    'ja': 'イギリス領インド洋地域'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac52'),
#   'alpha2Code': 'UM',
#   'alpha3Code': 'UMI',
#   'altSpellings': ['UM'],
#   'area': None,
#   'borders': [],
#   'callingCodes': [''],
#   'capital': '',
#   'currencies': ['USD'],
#   'demonym': 'American',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [],
#   'name': 'United States Minor Outlying Islands',
#   'nativeName': 'United States Minor Outlying Islands',
#   'numericCode': '581',
#   'population': 300,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Northern America',
#   'timezones': ['UTC-11:00', 'UTC-10:00', 'UTC+12:00'],
#   'topLevelDomain': ['.us'],
#   'translations': {'de': 'Kleinere Inselbesitzungen der Vereinigten Staaten',
#    'es': 'Islas Ultramarinas Menores de Estados Unidos',
#    'fr': 'Îles mineures éloignées des États-Unis',
#    'it': "Isole minori esterne degli Stati Uniti d'America",
#    'ja': '合衆国領有小離島'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac53'),
#   'alpha2Code': 'VG',
#   'alpha3Code': 'VGB',
#   'altSpellings': ['VG'],
#   'area': 151.0,
#   'borders': [],
#   'callingCodes': ['1284'],
#   'capital': 'Road Town',
#   'currencies': ['USD'],
#   'demonym': 'Virgin Islander',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [18.431383, -64.62305],
#   'name': 'Virgin Islands (British)',
#   'nativeName': 'British Virgin Islands',
#   'numericCode': '092',
#   'population': 28054,
#   'region': 'Americas',
#   'relevance': '0.5',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.vg'],
#   'translations': {'de': 'Britische Jungferninseln',
#    'es': 'Islas Vírgenes del Reino Unido',
#    'fr': 'Îles Vierges britanniques',
#    'it': 'Isole Vergini Britanniche',
#    'ja': 'イギリス領ヴァージン諸島'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac54'),
#   'alpha2Code': 'VI',
#   'alpha3Code': 'VIR',
#   'altSpellings': ['VI',
#    'USVI',
#    'American Virgin Islands',
#    'U.S. Virgin Islands'],
#   'area': 346.36,
#   'borders': [],
#   'callingCodes': ['1 340'],
#   'capital': 'Charlotte Amalie',
#   'currencies': ['USD'],
#   'demonym': 'Virgin Islander',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [18.34, -64.93],
#   'name': 'Virgin Islands (U.S.)',
#   'nativeName': 'Virgin Islands of the United States',
#   'numericCode': '850',
#   'population': 114743,
#   'region': 'Americas',
#   'relevance': '0.5',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.vi'],
#   'translations': {'de': 'Amerikanische Jungferninseln',
#    'es': 'Islas Vírgenes de los Estados Unidos',
#    'fr': 'Îles Vierges des États-Unis',
#    'it': 'Isole Vergini americane',
#    'ja': 'アメリカ領ヴァージン諸島'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac73'),
#   'alpha2Code': 'EC',
#   'alpha3Code': 'ECU',
#   'altSpellings': ['EC', 'Republic of Ecuador', 'República del Ecuador'],
#   'area': 276841.0,
#   'borders': ['COL', 'PER'],
#   'callingCodes': ['593'],
#   'capital': 'Quito',
#   'currencies': ['USD'],
#   'demonym': 'Ecuadorean',
#   'gini': 49.3,
#   'languages': ['es'],
#   'latlng': [-2.0, -77.5],
#   'name': 'Ecuador',
#   'nativeName': 'Ecuador',
#   'numericCode': '218',
#   'population': 16027500,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'South America',
#   'timezones': ['UTC-06:00', 'UTC-05:00'],
#   'topLevelDomain': ['.ec'],
#   'translations': {'de': 'Ecuador',
#    'es': 'Ecuador',
#    'fr': 'Équateur',
#    'it': 'Ecuador',
#    'ja': 'エクアドル'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac75'),
#   'alpha2Code': 'SV',
#   'alpha3Code': 'SLV',
#   'altSpellings': ['SV',
#    'Republic of El Salvador',
#    'República de El Salvador'],
#   'area': 21041.0,
#   'borders': ['GTM', 'HND'],
#   'callingCodes': ['503'],
#   'capital': 'San Salvador',
#   'currencies': ['SVC', 'USD'],
#   'demonym': 'Salvadoran',
#   'gini': 48.3,
#   'languages': ['es'],
#   'latlng': [13.83333333, -88.91666666],
#   'name': 'El Salvador',
#   'nativeName': 'El Salvador',
#   'numericCode': '222',
#   'population': 6401240,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Central America',
#   'timezones': ['UTC-06:00'],
#   'topLevelDomain': ['.sv'],
#   'translations': {'de': 'El Salvador',
#    'es': 'El Salvador',
#    'fr': 'Salvador',
#    'it': 'El Salvador',
#    'ja': 'エルサルバドル'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac8c'),
#   'alpha2Code': 'GU',
#   'alpha3Code': 'GUM',
#   'altSpellings': ['GU', 'Guåhån'],
#   'area': 549.0,
#   'borders': [],
#   'callingCodes': ['1671'],
#   'capital': 'Hagåtña',
#   'currencies': ['USD'],
#   'demonym': 'Guamanian',
#   'gini': None,
#   'languages': ['en', 'ch', 'es'],
#   'latlng': [13.46666666, 144.78333333],
#   'name': 'Guam',
#   'nativeName': 'Guam',
#   'numericCode': '316',
#   'population': 159358,
#   'region': 'Oceania',
#   'relevance': '0',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+10:00'],
#   'topLevelDomain': ['.gu'],
#   'translations': {'de': 'Guam',
#    'es': 'Guam',
#    'fr': 'Guam',
#    'it': 'Guam',
#    'ja': 'グアム'}},
#  {'_id': ObjectId('59e039121f7b2b002856ac92'),
#   'alpha2Code': 'HT',
#   'alpha3Code': 'HTI',
#   'altSpellings': ['HT',
#    'Republic of Haiti',
#    "République d'Haïti",
#    'Repiblik Ayiti'],
#   'area': 27750.0,
#   'borders': ['DOM'],
#   'callingCodes': ['509'],
#   'capital': 'Port-au-Prince',
#   'currencies': ['HTG', 'USD'],
#   'demonym': 'Haitian',
#   'gini': 59.2,
#   'languages': ['fr', 'ht'],
#   'latlng': [19.0, -72.41666666],
#   'name': 'Haiti',
#   'nativeName': 'Haïti',
#   'numericCode': '332',
#   'population': 10911819,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-05:00'],
#   'topLevelDomain': ['.ht'],
#   'translations': {'de': 'Haiti',
#    'es': 'Haiti',
#    'fr': 'Haïti',
#    'it': 'Haiti',
#    'ja': 'ハイチ'}},
#  {'_id': ObjectId('59e039121f7b2b002856acbc'),
#   'alpha2Code': 'MH',
#   'alpha3Code': 'MHL',
#   'altSpellings': ['MH',
#    'Republic of the Marshall Islands',
#    'Aolepān Aorōkin M̧ajeļ'],
#   'area': 181.0,
#   'borders': [],
#   'callingCodes': ['692'],
#   'capital': 'Majuro',
#   'currencies': ['USD'],
#   'demonym': 'Marshallese',
#   'gini': None,
#   'languages': ['en', 'mh'],
#   'latlng': [9.0, 168.0],
#   'name': 'Marshall Islands',
#   'nativeName': 'M̧ajeļ',
#   'numericCode': '584',
#   'population': 56086,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+12:00'],
#   'topLevelDomain': ['.mh'],
#   'translations': {'de': 'Marshallinseln',
#    'es': 'Islas Marshall',
#    'fr': 'Îles Marshall',
#    'it': 'Isole Marshall',
#    'ja': 'マーシャル諸島'}},
#  {'_id': ObjectId('59e039121f7b2b002856acc2'),
#   'alpha2Code': 'FM',
#   'alpha3Code': 'FSM',
#   'altSpellings': ['FM', 'Federated States of Micronesia'],
#   'area': 702.0,
#   'borders': [],
#   'callingCodes': ['691'],
#   'capital': 'Palikir',
#   'currencies': ['USD'],
#   'demonym': 'Micronesian',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [6.91666666, 158.25],
#   'name': 'Federated States of Micronesia',
#   'nativeName': 'Micronesia',
#   'numericCode': '583',
#   'population': 101351,
#   'region': 'Oceania',
#   'relevance': '0',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+10:00', 'UTC+11'],
#   'topLevelDomain': ['.fm'],
#   'translations': {'de': 'Mikronesien',
#    'es': 'Micronesia',
#    'fr': 'Micronésie',
#    'it': 'Micronesia',
#    'ja': 'ミクロネシア連邦'}},
#  {'_id': ObjectId('59e039121f7b2b002856acd7'),
#   'alpha2Code': 'MP',
#   'alpha3Code': 'MNP',
#   'altSpellings': ['MP',
#    'Commonwealth of the Northern Mariana Islands',
#    'Sankattan Siha Na Islas Mariånas'],
#   'area': 464.0,
#   'borders': [],
#   'callingCodes': ['1670'],
#   'capital': 'Saipan',
#   'currencies': ['USD'],
#   'demonym': 'American',
#   'gini': None,
#   'languages': ['en', 'ch'],
#   'latlng': [15.2, 145.75],
#   'name': 'Northern Mariana Islands',
#   'nativeName': 'Northern Mariana Islands',
#   'numericCode': '580',
#   'population': 53883,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+10:00'],
#   'topLevelDomain': ['.mp'],
#   'translations': {'de': 'Nördliche Marianen',
#    'es': 'Islas Marianas del Norte',
#    'fr': 'Îles Mariannes du Nord',
#    'it': 'Isole Marianne Settentrionali',
#    'ja': '北マリアナ諸島'}},
#  {'_id': ObjectId('59e039121f7b2b002856acdb'),
#   'alpha2Code': 'PW',
#   'alpha3Code': 'PLW',
#   'altSpellings': ['PW', 'Republic of Palau', 'Beluu er a Belau'],
#   'area': 459.0,
#   'borders': [],
#   'callingCodes': ['680'],
#   'capital': 'Ngerulmud',
#   'currencies': ['USD'],
#   'demonym': 'Palauan',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [7.5, 134.5],
#   'name': 'Palau',
#   'nativeName': 'Palau',
#   'numericCode': '585',
#   'population': 20901,
#   'region': 'Oceania',
#   'relevance': '0.5',
#   'subregion': 'Micronesia',
#   'timezones': ['UTC+09:00'],
#   'topLevelDomain': ['.pw'],
#   'translations': {'de': 'Palau',
#    'es': 'Palau',
#    'fr': 'Palaos',
#    'it': 'Palau',
#    'ja': 'パラオ'}},
#  {'_id': ObjectId('59e039121f7b2b002856acdd'),
#   'alpha2Code': 'PA',
#   'alpha3Code': 'PAN',
#   'altSpellings': ['PA', 'Republic of Panama', 'República de Panamá'],
#   'area': 75417.0,
#   'borders': ['COL', 'CRI'],
#   'callingCodes': ['507'],
#   'capital': 'Panama City',
#   'currencies': ['PAB', 'USD'],
#   'demonym': 'Panamanian',
#   'gini': 51.9,
#   'languages': ['es'],
#   'latlng': [9.0, -80.0],
#   'name': 'Panama',
#   'nativeName': 'Panamá',
#   'numericCode': '591',
#   'population': 3764166,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Central America',
#   'timezones': ['UTC-05:00'],
#   'topLevelDomain': ['.pa'],
#   'translations': {'de': 'Panama',
#    'es': 'Panamá',
#    'fr': 'Panama',
#    'it': 'Panama',
#    'ja': 'パナマ'}},
#  {'_id': ObjectId('59e039121f7b2b002856ace5'),
#   'alpha2Code': 'PR',
#   'alpha3Code': 'PRI',
#   'altSpellings': ['PR',
#    'Commonwealth of Puerto Rico',
#    'Estado Libre Asociado de Puerto Rico'],
#   'area': 8870.0,
#   'borders': [],
#   'callingCodes': ['1787', '1939'],
#   'capital': 'San Juan',
#   'currencies': ['USD'],
#   'demonym': 'Puerto Rican',
#   'gini': None,
#   'languages': ['es', 'en'],
#   'latlng': [18.25, -66.5],
#   'name': 'Puerto Rico',
#   'nativeName': 'Puerto Rico',
#   'numericCode': '630',
#   'population': 3548397,
#   'region': 'Americas',
#   'relevance': '0',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.pr'],
#   'translations': {'de': 'Puerto Rico',
#    'es': 'Puerto Rico',
#    'fr': 'Porto Rico',
#    'it': 'Porto Rico',
#    'ja': 'プエルトリコ'}},
#  {'_id': ObjectId('59e039121f7b2b002856ad12'),
#   'alpha2Code': 'TL',
#   'alpha3Code': 'TLS',
#   'altSpellings': ['TL',
#    'East Timor',
#    'Democratic Republic of Timor-Leste',
#    'República Democrática de Timor-Leste',
#    'Repúblika Demokrátika Timór-Leste'],
#   'area': 14874.0,
#   'borders': ['IDN'],
#   'callingCodes': ['670'],
#   'capital': 'Dili',
#   'currencies': ['USD'],
#   'demonym': 'East Timorese',
#   'gini': 31.9,
#   'languages': ['pt'],
#   'latlng': [-8.83333333, 125.91666666],
#   'name': 'East Timor',
#   'nativeName': 'Timor-Leste',
#   'numericCode': '626',
#   'population': 1212107,
#   'region': 'Asia',
#   'relevance': '0',
#   'subregion': 'South-Eastern Asia',
#   'timezones': ['UTC+09:00'],
#   'topLevelDomain': ['.tl'],
#   'translations': {'de': 'Timor-Leste',
#    'es': 'Timor Oriental',
#    'fr': 'Timor oriental',
#    'it': 'Timor Est',
#    'ja': '東ティモール'}},
#  {'_id': ObjectId('59e039121f7b2b002856ad1a'),
#   'alpha2Code': 'TC',
#   'alpha3Code': 'TCA',
#   'altSpellings': ['TC'],
#   'area': 948.0,
#   'borders': [],
#   'callingCodes': ['1649'],
#   'capital': 'Cockburn Town',
#   'currencies': ['USD'],
#   'demonym': 'Turks and Caicos Islander',
#   'gini': None,
#   'languages': ['en'],
#   'latlng': [21.75, -71.58333333],
#   'name': 'Turks and Caicos Islands',
#   'nativeName': 'Turks and Caicos Islands',
#   'numericCode': '796',
#   'population': 31458,
#   'region': 'Americas',
#   'relevance': '0.5',
#   'subregion': 'Caribbean',
#   'timezones': ['UTC-04:00'],
#   'topLevelDomain': ['.tc'],
#   'translations': {'de': 'Turks- und Caicosinseln',
#    'es': 'Islas Turks y Caicos',
#    'fr': 'Îles Turques-et-Caïques',
#    'it': 'Isole Turks e Caicos',
#    'ja': 'タークス・カイコス諸島'}},
#  {'_id': ObjectId('59e039121f7b2b002856ad20'),
#   'alpha2Code': 'US',
#   'alpha3Code': 'USA',
#   'altSpellings': ['US', 'USA', 'United States of America'],
#   'area': 9629091.0,
#   'borders': ['CAN', 'MEX'],
#   'callingCodes': ['1'],
#   'capital': 'Washington, D.C.',
#   'currencies': ['USD', 'USN', 'USS'],
#   'demonym': 'American',
#   'gini': 48.0,
#   'languages': ['en'],
#   'latlng': [38.0, -97.0],
#   'name': 'United States',
#   'nativeName': 'United States',
#   'numericCode': '840',
#   'population': 321645000,
#   'region': 'Americas',
#   'relevance': '3.5',
#   'subregion': 'Northern America',
#   'timezones': ['UTC-12:00',
#    'UTC-11:00',
#    'UTC-10:00',
#    'UTC-09:00',
#    'UTC-08:00',
#    'UTC-07:00',
#    'UTC-06:00',
#    'UTC-05:00',
#    'UTC-04:00',
#    'UTC+10:00',
#    'UTC+12:00'],
#   'topLevelDomain': ['.us'],
#   'translations': {'de': 'Vereinigte Staaten von Amerika',
#    'es': 'Estados Unidos',
#    'fr': 'États-Unis',
#    'it': "Stati Uniti D'America",
#    'ja': 'アメリカ合衆国'}},
#  {'_id': ObjectId('59e039121f7b2b002856ad2a'),
#   'alpha2Code': 'ZW',
#   'alpha3Code': 'ZWE',
#   'altSpellings': ['ZW', 'Republic of Zimbabwe'],
#   'area': 390757.0,
#   'borders': ['BWA', 'MOZ', 'ZAF', 'ZMB'],
#   'callingCodes': ['263'],
#   'capital': 'Harare',
#   'currencies': ['USD'],
#   'demonym': 'Zimbabwean',
#   'gini': None,
#   'languages': ['en', 'sn', 'nd'],
#   'latlng': [-20.0, 30.0],
#   'name': 'Zimbabwe',
#   'nativeName': 'Zimbabwe',
#   'numericCode': '716',
#   'population': 13061239,
#   'region': 'Africa',
#   'relevance': '0',
#   'subregion': 'Eastern Africa',
#   'timezones': ['UTC+02:00'],
#   'topLevelDomain': ['.zw'],
#   'translations': {'de': 'Simbabwe',
#    'es': 'Zimbabue',
#    'fr': 'Zimbabwe',
#    'it': 'Zimbabwe',
#    'ja': 'ジンバブエ'}}]

# %%
# We can replicate the same thing in the docker/app/main.py file
